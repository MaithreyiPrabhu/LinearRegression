# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %matplotlib inline

# %%
data = pd.read_csv('Advertising.csv', index_col=0)

# %%
data
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Simple Linear regression

# %%
## Seeing effect of TV on sales

plt.figure(figsize=(16,8))
plt.scatter(data['TV'], data['sales'], c='black')
plt.xlabel('Money spend on TV advertisements')
plt.ylabel('Sales in 1000 $')
# Out:
# Text(0, 0.5, 'Sales in 1000 $')

# %%
## Seeing effect of radio on sales

plt.figure(figsize=(16,8))
plt.scatter(data['radio'], data['sales'], c='black')
plt.xlabel('Money spend on TV advertisements')
plt.ylabel('Sales in 1000 $')
# Out:
# Text(0, 0.5, 'Sales in 1000 $')

# %%
## Seeing effect of newspaper on sales

plt.figure(figsize=(16,8))
plt.scatter(data['newspaper'], data['sales'], c='black')
plt.xlabel('Money spend on TV advertisements')
plt.ylabel('Sales in 1000 $')
# Out:
# Text(0, 0.5, 'Sales in 1000 $')

# %%
## TV and sales

#Convert to 2D numpy array
X = data['TV'].values.reshape(-1,1)
Y = data['sales'].values.reshape(-1,1)

#Call the regression model
regression = LinearRegression()

#Fit the model to data
regression.fit(X,Y)


print(regression.intercept_[0], regression.coef_[0][0])
## We get constat of 7.03 and a slope of 0.0475
## Positive constant and positive slope

predictions = regression.predict(X)
plt.figure(figsize=(16,8))
plt.scatter(X,Y, c='black')
plt.xlabel('Money spend on TV advertisements')
plt.ylabel('Sales in 1000 $')
plt.plot(X, predictions, c='blue', linewidth=2)
# Out:
# 7.032593549127695 0.04753664043301975

# %%
## Assess the quality of the model
X = data['TV']
Y = data['sales']
linearmodel = sm.add_constant(X)
#Estimator Orinary least square
estimator = sm.OLS(Y, linearmodel).fit()
print(estimator.summary())

## Report reading
## R squared value of 0.612 is acheived. Only 60% of the variablity is explained. Not very good.
## F-statisctics is 312 which is much larger than 1. Seems the model is a little good.
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Sun, 24 May 2020   Prob (F-statistic):           1.47e-42
# Time:                        14:36:32   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
 ## radio and sales

#Convert to 2D numpy array
X = data['radio'].values.reshape(-1,1)
Y = data['sales'].values.reshape(-1,1)

#Call the regression model
regression = LinearRegression()

#Fit the model to data
regression.fit(X,Y)


print(regression.intercept_[0], regression.coef_[0][0])
## We get constat of 7.03 and a slope of 0.0475
## Positive constant and positive slope

predictions = regression.predict(X)
plt.figure(figsize=(16,8))
plt.scatter(X,Y, c='black')
plt.xlabel('Money spend on radio advertisements')
plt.ylabel('Sales in 1000 $')
plt.plot(X, predictions, c='blue', linewidth=2)
# Out:
# 9.311638095158283 0.20249578339243965

# %%
## Assess the quality of the model
X = data['radio']
Y = data['sales']
linearmodel = sm.add_constant(X)
#Estimator Orinary least square
estimator = sm.OLS(Y, linearmodel).fit()
print(estimator.summary())

## Report reading
## R squared value of 0.332 is acheived. Only 30% of the variablity is explained. Not  good.
## F-statisctics is 98 which is much larger than 1. Seems the model is a little good.
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     98.42
# Date:                Sun, 24 May 2020   Prob (F-statistic):           4.35e-19
# Time:                        14:38:04   Log-Likelihood:                -573.34
# No. Observations:                 200   AIC:                             1151.
# Df Residuals:                     198   BIC:                             1157.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.3116      0.563     16.542      0.000       8.202      10.422
# ...

# %%
 ## radio and sales

#Convert to 2D numpy array
X = data['newspaper'].values.reshape(-1,1)
Y = data['sales'].values.reshape(-1,1)

#Call the regression model
regression = LinearRegression()

#Fit the model to data
regression.fit(X,Y)


print(regression.intercept_[0], regression.coef_[0][0])
## We get constat of 7.03 and a slope of 0.0475
## Positive constant and positive slope

predictions = regression.predict(X)
plt.figure(figsize=(16,8))
plt.scatter(X,Y, c='black')
plt.xlabel('Money spend on newspaper advertisements')
plt.ylabel('Sales in 1000 $')
plt.plot(X, predictions, c='blue', linewidth=2)
# Out:
# 12.35140706927816 0.05469309847227336

# %%
## Assess the quality of the model
X = data['newspaper']
Y = data['sales']
linearmodel = sm.add_constant(X)
#Estimator Orinary least square
estimator = sm.OLS(Y, linearmodel).fit()
print(estimator.summary())

## Report reading
## R squared value of 0.052 is acheived. Only 30% of the variablity is explained. Not  good.
## F-statisctics is 10 which is  larger than 1. Seems the model is a little good.
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     10.89
# Date:                Sun, 24 May 2020   Prob (F-statistic):            0.00115
# Time:                        14:39:00   Log-Likelihood:                -608.34
# No. Observations:                 200   AIC:                             1221.
# Df Residuals:                     198   BIC:                             1227.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.3514      0.621     19.876      0.000      11.126      13.577
# ...

# %% [markdown]
# ### Multiple Linear Regression

# %%
## Take all features. The news paper, radio and TV on sales data
Y = data['sales'].values.reshape(-1,1)
X_features = data.drop(['sales'], axis=1)


#Call the regression model
regression = LinearRegression()

#Fit the model to data
regression.fit(X_features,Y)


print(regression.intercept_[0])
## We get constat of 7.03 and a slope of 0.0475
# Out:
# 2.938889369459412

# %%
## Assess the quality of the model
X = np.column_stack((data['TV'], data['radio'],data['newspaper']))
Y = data['sales'].values.reshape(-1,1)
linearmodel = sm.add_constant(X)
estimator = sm.OLS(Y,linearmodel).fit()
print(estimator.summary())
## R squared is 0.897 which is good
## F-statistic is 570 which is very much higher than 1
## But here p value for newspaper is 0.860 which is higher than 0.05 which means newspaper is not relevant for our model and you can take it out
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Sun, 24 May 2020   Prob (F-statistic):           1.58e-96
# Time:                        14:52:37   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
predictions = regression.predict(X)
plt.figure(figsize=(16,8))
plt.scatter(X_features,Y, c='black')
plt.xlabel('Money spend on newspaper advertisements')
plt.ylabel('Sales in 1000 $')
plt.plot(X, predictions, c='blue', linewidth=2)
